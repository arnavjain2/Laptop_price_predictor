# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('laptop_data.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %% [markdown]
# droping useless column

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# ### COMPANY COLUMN

# %%
df['Company'].unique()
# Out:
# array(['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI',
#        'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer',
#        'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG'], dtype=object)

# %% [markdown]
# finding number of laptop of companies

# %%
df['Company'].value_counts().plot(kind='bar')
# DELL , LENOVO AND HP HAVE MAXIMUM LAPTOPS IN THIS DATA
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x = df['Company'] ,y =  df['Price'])
plt.xticks(rotation='vertical')
plt.show()
#RAZER HAS MOST EXPENSIVEW LAPTOPS FOLLWED NY LG , GOOGLE , MICROSOFT

# %%
sns.scatterplot(x=df['Company'] ,y= df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Type Name Column

# %%
df['TypeName'].unique()
# Out:
# array(['Ultrabook', 'Notebook', 'Netbook', 'Gaming', '2 in 1 Convertible',
#        'Workstation'], dtype=object)

# %%
df['TypeName'].value_counts().plot(kind='bar')
# POPULATIRY LEVEL IS NOTEBOOK >GAMING > ULTRABOOK>2 IN 1 > WORKSTATION > NETBOOK
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x= df['TypeName'] , y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# WORKSTATION ARE THE MOST EXPENSIVE FOLLOWED NY GAMING AND ULTRABOOK

# %%
sns.scatterplot(x=df['TypeName'] ,y= df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Inches

# %%
df['Inches'].unique()
# Out:
# array([13.3, 15.6, 15.4, 14. , 12. , 11.6, 17.3, 10.1, 13.5, 12.5, 13. ,
#        18.4, 13.9, 12.3, 17. , 15. , 14.1, 11.3])

# %%
df['Inches'].value_counts().plot(kind='bar')
# 15.6 incles laptop are most popular
# Out:
# <Axes: xlabel='Inches'>

# %%
df['Inches'].value_counts().plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Inches'].describe().drop('count').plot(kind='bar')
# Out:
# <Axes: >

# %%
# df['Inches'] = np.log(df['Inches'])

# %%
sns.barplot(x= df['Inches'] , y = df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Inches'] ,y= df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### ScreenResolution

# %%
df['ScreenResolution'].value_counts().plot(kind='bar')
# some laptops are touchscreen
# Out:
# <Axes: xlabel='ScreenResolution'>

# %%
df['touchscreen'] = df['ScreenResolution'].apply(lambda x : 1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches                 ScreenResolution  \
# 408   Lenovo  Notebook    15.6                Full HD 1920x1080
# 165      MSI    Gaming    15.6      IPS Panel Full HD 1920x1080
# 211     Asus    Gaming    17.3                Full HD 1920x1080
# 1009      HP  Notebook    14.0                         1366x768
# 858     Dell  Notebook    13.3  Full HD / Touchscreen 1920x1080
#
#                               Cpu   Ram                Memory  \
# 408      Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 165   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 211   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 1009   Intel Core i3 7100U 2.4GHz   4GB             500GB HDD
# 858    Intel Core i5 6200U 2.3GHz   8GB               1TB HDD
#
#                           Gpu       OpSys  Weight     Price  touchscreen
# 408     Intel HD Graphics 520  Windows 10   2.2kg  21791.52            0
# 165   Nvidia GeForce GTX 1060  Windows 10   2.4kg  95850.72            0
# 211   Nvidia GeForce GTX 1050  Windows 10   2.9kg  74964.96            0
# 1009    Intel HD Graphics 620  Windows 10  1.64kg  36443.52            0
# 858     Intel HD Graphics 520  Windows 10  1.62kg  34578.72            1

# %%
df['ScreenResolution'] = df['ScreenResolution'].str.replace('Touchscreen','')

# %%
temp = df['ScreenResolution'].str.split('x' , expand=True)

# %%
df['y_res'] =  temp[1]

# %%
df['x_res'] = temp[0].apply(lambda x : ''.join(x.split()[-1::]))

# %%
df['x_res'] = df['x_res'].astype(int)
df['y_res'] = df['y_res'].astype(int)

# %%
df['ScreenResolution'] = df['ScreenResolution'].apply(lambda x : 1 if 'IPS' in x else 0)

# %%
df['IPS'] = df['ScreenResolution']

# %%
df.head()
# Out:
#   Company   TypeName  Inches  ScreenResolution                         Cpu  \
# 0   Apple  Ultrabook    13.3                 1        Intel Core i5 2.3GHz
# 1   Apple  Ultrabook    13.3                 0        Intel Core i5 1.8GHz
# 2      HP   Notebook    15.6                 0  Intel Core i5 7200U 2.5GHz
# 3   Apple  Ultrabook    15.4                 1        Intel Core i7 2.7GHz
# 4   Apple  Ultrabook    13.3                 1        Intel Core i5 3.1GHz
#
#     Ram               Memory                           Gpu  OpSys  Weight  \
# 0   8GB            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1   8GB  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2   8GB            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3  16GB            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4   8GB            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#          Price  touchscreen  y_res  x_res  IPS
# 0   71378.6832            0   1600   2560    1
# 1   47895.5232            0    900   1440    0
# 2   30636.0000            0   1080   1920    0
# 3  135195.3360            0   1800   2880    1
# 4   96095.8080            0   1600   2560    1

# %%
df.drop('ScreenResolution',axis=1 , inplace=True)

# %% [markdown]
# ### CPU

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: count, Length: 118, dtype: int64

# %%
cpu_type  = df['Cpu'].apply(lambda x: 'Intel' if "Intel"in x else 'AMD')
cpu_type.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
df['Cpu'] = df['Cpu'].apply(lambda x : " ".join(x.split()[0:3]))

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x= df['Cpu'] , y= df['Price'])
plt.xticks(rotation= 'vertical')
plt.show()

# %% [markdown]
# ### RAM

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
df['Ram'] = df['Ram'].str.replace('GB','').str.strip()

# %%
df['Ram'] = df['Ram'].astype(int)

# %%
df['Ram'].describe().drop('count').plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### MEMORY

# %%
df['Memory'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Memory'>

# %%
df['Memory'] = df['Memory'].str.replace('GB','').str.replace('TB','000')
df['Memory'] = df['Memory'].str.replace('1.0000','1000')
df['HDD']= df['Memory'].apply(lambda x : 1 if 'HDD' in x else 0)
df['SSD']= df['Memory'].apply(lambda x : 1 if 'SSD' in x else 0)
df['Flash_Storage']= df['Memory'].apply(lambda x : 1 if 'Flash Storage' in x else 0)
df['Hybrid'] = df['Memory'].apply(lambda x: 1 if 'Hybrid' in x else 0 )

# %%
df['Memory'] = df['Memory'].str.split(" ")

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram                 Memory  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8             [128, SSD]
# 1   Apple  Ultrabook    13.3  Intel Core i5    8  [128, Flash, Storage]
# 2      HP   Notebook    15.6  Intel Core i5    8             [256, SSD]
# 3   Apple  Ultrabook    15.4  Intel Core i7   16             [512, SSD]
# 4   Apple  Ultrabook    13.3  Intel Core i5    8             [256, SSD]
#
#                             Gpu  OpSys  Weight        Price  touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832            0
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232            0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000            0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080            0
#
#    y_res  x_res  IPS  HDD  SSD  Flash_Storage  Hybrid
# 0   1600   2560    1    0    1              0       0
# 1    900   1440    0    0    0              1       0
# 2   1080   1920    0    0    1              0       0
# 3   1800   2880    1    0    1              0       0
# 4   1600   2560    1    0    1              0       0

# %%
df['SSD'] = df['Memory'].apply(lambda x : x[x.index('SSD')-1] if 'SSD' in x else 0 )

# %%
df['HDD'] = df['Memory'].apply(lambda x : x[x.index('HDD')-1] if 'HDD' in x else 0 )
df['Flash_Storage'] = df['Memory'].apply(lambda x : x[x.index('Flash')-1] if 'Flash' in x else 0 )

# %%
df[(df['HDD'] != 0) & (df['SSD'] !=0)]
# Out:
#      Company  TypeName  Inches             Cpu  Ram  \
# 21    Lenovo    Gaming    15.6   Intel Core i5    8
# 37      Dell  Notebook    17.3   Intel Core i5    8
# 41      Dell    Gaming    15.6   Intel Core i7   16
# 47      Asus    Gaming    17.3  AMD Ryzen 1700    8
# 58       MSI    Gaming    17.3   Intel Core i7   16
# ...      ...       ...     ...             ...  ...
# 1238     MSI    Gaming    15.6   Intel Core i7    8
# 1245    Asus    Gaming    15.6   Intel Core i7   16
# 1247    Asus    Gaming    15.6   Intel Core i7   16
# 1256    Asus    Gaming    17.3   Intel Core i7   16
# 1259     MSI    Gaming    15.6   Intel Core i7    8
#
#                           Memory                         Gpu       OpSys  \
# 21    [128, SSD, +, , 1000, HDD]     Nvidia GeForce GTX 1050  Windows 10
# 37    [128, SSD, +, , 1000, HDD]              AMD Radeon 530  Windows 10
# 41    [256, SSD, +, , 1000, HDD]     Nvidia GeForce GTX 1060  Windows 10
# 47    [256, SSD, +, , 1000, HDD]           AMD Radeon RX 580  Windows 10
# 58    [256, SSD, +, , 2000, HDD]     Nvidia GeForce GTX 1070  Windows 10
# ...                          ...                         ...         ...
# 1238  [128, SSD, +, , 1000, HDD]     Nvidia GeForce GTX 960M  Windows 10
# 1245  [256, SSD, +, , 1000, HDD]  Nvidia GeForce GTX 1050 Ti  Windows 10
# 1247  [256, SSD, +, , 1000, HDD]     Nvidia GeForce GTX 1070  Windows 10
# 1256  [128, SSD, +, , 1000, HDD]     Nvidia GeForce GTX 970M  Windows 10
# 1259  [128, SSD, +, , 1000, HDD]     Nvidia GeForce GTX 960M  Windows 10
#
#       Weight      Price  touchscreen  y_res  x_res  IPS   HDD  SSD  \
# 21     2.5kg   53226.72            0   1080   1920    1  1000  128
# 37     2.8kg   52161.12            0   1080   1920    1  1000  128
# 41    2.65kg   79866.72            0   1080   1920    1  1000  256
# 47     3.2kg   69210.72            0   1080   1920    0  1000  256
# 58    2.43kg  130482.72            0   1080   1920    0  2000  256
# ...      ...        ...          ...    ...    ...  ...   ...  ...
# 1238   2.3kg   62284.32            0   1080   1920    0  1000  128
# 1245   2.5kg   85248.00            0   1080   1920    1  1000  256
# 1247  2.34kg  123876.00            0   1080   1920    1  1000  256
# 1256   4.0kg  101232.00            0   1080   1920    1  1000  128
# 1259   2.4kg   65481.12            0   1080   1920    0  1000  128
#
#      Flash_Storage  Hybrid
# 21               0       0
# 37               0       0
# 41               0       0
# 47               0       0
# 58               0       0
# ...            ...     ...
# 1238             0       0
# 1245             0       0
# 1247             0       0
# 1256             0       0
# 1259             0       0
#
# [200 rows x 18 columns]

# %%
df.drop('Memory' ,axis=1, inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches            Cpu  Ram  \
# 0   Apple  Ultrabook    13.3  Intel Core i5    8
# 1   Apple  Ultrabook    13.3  Intel Core i5    8
# 2      HP   Notebook    15.6  Intel Core i5    8
# 3   Apple  Ultrabook    15.4  Intel Core i7   16
# 4   Apple  Ultrabook    13.3  Intel Core i5    8
#
#                             Gpu  OpSys  Weight        Price  touchscreen  \
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832            0
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232            0
# 2         Intel HD Graphics 620  No OS  1.86kg   30636.0000            0
# 3            AMD Radeon Pro 455  macOS  1.83kg  135195.3360            0
# 4  Intel Iris Plus Graphics 650  macOS  1.37kg   96095.8080            0
#
#    y_res  x_res  IPS HDD  SSD Flash_Storage  Hybrid
# 0   1600   2560    1   0  128             0       0
# 1    900   1440    0   0    0           128       0
# 2   1080   1920    0   0  256             0       0
# 3   1800   2880    1   0  512             0       0
# 4   1600   2560    1   0  256             0       0

# %% [markdown]
# ### GPU

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu_Brand'] = df['Gpu'].apply(lambda x: x.split()[0])

# %%
df['Gpu_Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu_Brand'>

# %%
df= df[df['Gpu_Brand'] != 'ARM']

# %%
new = df['Gpu'].apply(lambda x : " ".join(x.split()[-1::]))
new1 = df['Gpu'].apply(lambda x : " ".join(x.split()[0:1:]))
df['Gpu'] =  new1 + " " + new

# %%
# df['Gpu'] = df['Gpu'].str.replace('GeForce','').str.replace('Graphics',' ').str.replace('GTX','').str.replace('  ',' ')

# %%
# [i for i in df['Gpu'] if '1080' in i]

# %%
# [i for i in df['Gpu'] if 'Graphics' in i]

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel 620         351
# Intel 520         185
# Nvidia 1050        66
# Nvidia 940MX       52
# Nvidia 1060        48
#                  ...
# AMD R17M-M1-70      1
# Nvidia SLI          1
# AMD 555             1
# AMD 455             1
# Nvidia M3000M       1
# Name: count, Length: 89, dtype: int64

# %% [markdown]
# ### OpSys

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
def change(inp):
    if 'Windows' in inp:
        return 'Windows'
    if 'Mac' in inp or 'mac' in inp:
        return 'Mac'
    else:
        return 'Others'

# %%
df['OpSys'] = df['OpSys'].apply(lambda x: change(x))

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %% [markdown]
# ### weight

# %%
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df['Weight'] = df['Weight'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1302 entries, 0 to 1302
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1302 non-null   object
#  1   TypeName       1302 non-null   object
#  2   Inches         1302 non-null   float64
#  3   Cpu            1302 non-null   object
#  4   Ram            1302 non-null   int32
#  5   Gpu            1302 non-null   object
#  6   OpSys          1302 non-null   object
#  7   Weight         1302 non-null   float64
#  8   Price          1302 non-null   float64
#  9   touchscreen    1302 non-null   int64
#  10  y_res          1302 non-null   int32
#  11  x_res          1302 non-null   int32
#  12  IPS            1302 non-null   int64
#  13  HDD            1302 non-null   object
#  14  SSD            1302 non-null   object
#  15  Flash_Storage  1302 non-null   object
#  16  Hybrid         1302 non-null   int64
#  17  Gpu_Brand      1302 non-null   object
# dtypes: float64(3), int32(3), int64(3), object(9)
# memory usage: 178.0+ KB

# %%
df['HDD'] = df['HDD'].astype(int)
df['SSD'] = df['SSD'].astype(int)
df['Flash_Storage'] = df['Flash_Storage'].astype(int)

# %% [markdown]
# ### heatmap

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     Price  touchscreen     y_res  \
# Inches         1.000000  0.237129  0.827397  0.067329    -0.359514 -0.092934
# Ram            0.237129  1.000000  0.383362  0.742905     0.118875  0.426357
# Weight         0.827397  0.383362  1.000000  0.209867    -0.293004 -0.052041
# Price          0.067329  0.742905  0.209867  1.000000     0.192917  0.554591
# touchscreen   -0.359514  0.118875 -0.293004  0.192917     1.000000  0.355756
# y_res         -0.092934  0.426357 -0.052041  0.554591     0.355756  1.000000
# x_res         -0.069875  0.434095 -0.031866  0.557369     0.350097  0.994480
# IPS           -0.112726  0.207949  0.018643  0.253320     0.148026  0.287404
# HDD            0.531531  0.097399  0.515632 -0.096122    -0.208805 -0.136621
# SSD           -0.110636  0.604088 -0.063507  0.676066     0.256758  0.526886
# Flash_Storage -0.228868 -0.059612 -0.179165 -0.040067    -0.020809  0.014996
# Hybrid         0.049481  0.033795  0.090125  0.007003    -0.039990 -0.005575
#
#                   x_res       IPS       HDD       SSD  Flash_Storage    Hybrid
# Inches        -0.069875 -0.112726  0.531531 -0.110636      -0.228868  0.049481
# Ram            0.434095  0.207949  0.097399  0.604088      -0.059612  0.033795
# Weight        -0.031866  0.018643  0.515632 -0.063507      -0.179165  0.090125
# Price          0.557369  0.253320 -0.096122  0.676066      -0.040067  0.007003
# touchscreen    0.350097  0.148026 -0.208805  0.256758      -0.020809 -0.039990
# y_res          0.994480  0.287404 -0.136621  0.526886       0.014996 -0.005575
# x_res          1.000000  0.280588 -0.125343  0.534516      -0.017177 -0.004011
# IPS            0.280588  1.000000 -0.092953  0.228870       0.068616 -0.024264
# HDD           -0.125343 -0.092953  1.000000 -0.400915      -0.117311 -0.077548
# SSD            0.534516  0.228870 -0.400915  1.000000      -0.148321 -0.062066
# Flash_Storage -0.017177  0.068616 -0.117311 -0.148321       1.000000 -0.014451
# Hybrid        -0.004011 -0.024264 -0.077548 -0.062066      -0.014451  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True) , annot=True)
# Out:
# <Axes: >

# %%
df.sample(5)
# Out:
#       Company   TypeName  Inches            Cpu  Ram           Gpu    OpSys  \
# 1209     Asus     Gaming    15.6  Intel Core i7   16   Nvidia 1070  Windows
# 491   Toshiba  Ultrabook    13.3  Intel Core i7   32     Intel 620  Windows
# 1231    Razer     Gaming    14.0  Intel Core i7   16   Nvidia 1060  Windows
# 38         HP   Notebook    15.6  Intel Core i5    4     Intel 620  Windows
# 1134     Acer   Notebook    15.6  Intel Core i5    4  Nvidia 940MX  Windows
#
#       Weight        Price  touchscreen  y_res  x_res  IPS   HDD   SSD  \
# 1209    2.20  130482.7200            0   1080   1920    0  1000   256
# 491     1.05  149130.7200            1   1080   1920    0     0   512
# 1231    1.95  186426.7200            0   1080   1920    0     0  1000
# 38      1.86   26037.4032            0    768   1366    0  1000     0
# 1134    2.23   32820.4800            0   1080   1920    0  1000     0
#
#       Flash_Storage  Hybrid Gpu_Brand
# 1209              0       0    Nvidia
# 491               0       0     Intel
# 1231              0       0    Nvidia
# 38                0       0     Intel
# 1134              0       0    Nvidia

# %%
df.drop(['Flash_Storage','Hybrid'], axis=1,inplace=True)

# %% [markdown]
# ### Creating a model

# %% [markdown]
# removing skewness from price by applying log transformation

# %%
df['Price'].describe().plot(kind='box')
# Out:
# <Axes: >

# %%
X = df.drop('Price',axis=1)
y = np.log(df['Price'])

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
ohe.fit(X[['Company', 'TypeName' , 'Cpu','Gpu', 'OpSys','Gpu_Brand']])
# Out:
# OneHotEncoder()

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from sklearn.metrics import r2_score , mean_absolute_error , mean_squared_error
cf = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Company', 'TypeName' , 'Cpu', 'Gpu', 'OpSys','Gpu_Brand']),remainder='passthrough')

# %%
from sklearn.model_selection import train_test_split
r2score = []
meanerror = []
for i in range(1000):
    x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=i)
    lr = XGBRegressor()
    pipe = make_pipeline(cf,lr)
    pipe.fit(x_train,y_train)
    y_pred = pipe.predict(x_test)
    r2score.append(r2_score(y_test,y_pred)) 
    meanerror.append(mean_absolute_error(y_test,y_pred))

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=np.argmax(r2score)) 
lr =XGBRegressor()
pipe = make_pipeline(cf,lr)
pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)
print('r2_sore:',r2_score(y_test,y_pred))
print('mean_absolute_error:', mean_absolute_error(y_test,y_pred))
print('mean_squared_error', mean_squared_error(y_test,y_pred))
# Out:
# r2_sore: 0.9390100978153857
# mean_absolute_error: 0.12288633804554012
# mean_squared_error 0.026259219787966023

# %%
final = pd.DataFrame({'Actual': np.exp(y_test) ,"predicted": np.exp(y_pred) , 'diff': np.exp(y_test)- np.exp(y_pred)})

# %%
X.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Cpu', 'Ram', 'Gpu', 'OpSys', 'Weight',
#        'touchscreen', 'y_res', 'x_res', 'IPS', 'HDD', 'SSD', 'Gpu_Brand'],
#       dtype='object')

# %%
print(np.max(final['diff']))
print(np.min(final['diff']))
# Out:
# 49791.36843750009
# -25972.840624999983

# %%
import pickle
pickle.dump(pipe,open('linearregression.pkl','wb'))

# %%
sns.scatterplot(x=np.exp(y_test),y= np.exp(y_pred) , hue = x_test['Company'] )
# Out:
# <Axes: xlabel='Price'>
